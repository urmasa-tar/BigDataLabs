# %%
import os

import subprocess
import sys

import numpy as np
import matplotlib.pyplot as plt

import re

# %% [markdown]
# <h4>1) Work with directory<h4>
# <code>os.chdir('dir')</code> <p> - to set directory in dir. By default set to build file directory</p>

# %%
# to now space around us
original_directory = os.getcwd()
directory_path = '/data'

try:
    os.chdir(directory_path)
except FileNotFoundError:
    print(f"Error: Path '{directory_path}' doeen't exist.")
    # os.chdir()
    print(f"Current directory is {os.getcwd()}")
except PermissionError:
    print(f"No rights for '{directory_path}'.")
except Exception as e:
    print(f"Some unecpeected error - {e}")
# Out:
# Error: Path '/data' doeen't exist.
# Current directory is c:\Users\urmasa\Documents\madi\bigData\BigDataLabs\lab01

# %% [markdown]
# <h5>2) Gistogramm by Vector<h5>
# <p>Criate an vector with <code>np.random.rand()</code></p>
# <p>Build gistogram by vector of (0, 1) <code>plt.hits()</code></p>

# %%
X = np.random.rand(100)  # 100 rand from 0 to 1
                        

# Создание гистограммы
plt.hist(X, bins=np.arange(0, 1.1, 0.1), edgecolor='black')

# Настройка графика
plt.title('Hist for every value from 0 to 1')
plt.xlabel('Value')
plt.ylabel('Frequancy')

# Отображение графика
plt.show()

# %% [markdown]
# <h5>3) Data save</h5>

# %%
folder_path = "resPath"
os.makedirs(folder_path, exist_ok=True)
os.chdir(folder_path)
# Save as txt
np.savetxt('vector.txt', X, delimiter=',')

# Save as csv
np.savetxt('vector.csv', X, delimiter=',')

plt.hist(X, bins=np.arange(0, 1.1, 0.1), edgecolor='black')
plt.title('Hist for every value from 0 to 1')
plt.xlabel('Value')
plt.ylabel('Frequancy')

# Сохранение в JPG
plt.savefig('histogram.jpg')

# Сохранение в SVG
plt.savefig('histogram.svg')

plt.show()

os.chdir(original_directory)

# %% [markdown]
# <h5>4) Most common structers</h5>
#
# <p><code>numeric()</code> - </p>
# <p><code>list()</code> - </p>
# <p><code>dict()</code> - </p>
# <p><code>set()</code> - </p>

# %%
# Work with numeric type(int and float in python) and list type
# Создаем массив с числовыми данными
numeric_data = np.array([1, 2, 3, 4, 5])

# Выводим массив
print("Числовой массив:", numeric_data)

# Выполняем арифметические операции
sum_values = np.sum(numeric_data)
mean_value = np.mean(numeric_data)

# Выводим результаты
print("Сумма значений:", sum_values)
print("Среднее значение:", mean_value)

# Пример работы с float
float_data = np.array([1.5, 2.5, 3.5, 4.5, 5.5])
print("Массив с плавающей точкой:", float_data)

# Выполняем операции с плавающей точкой
sum_float = np.sum(float_data)
mean_float = np.mean(float_data)

# Выводим результаты
print("Сумма значений с плавающей точкой:", sum_float, "тип элемента ", type(sum_float))
print("Среднее значение с плавающей точкой:", mean_float, "тип элемента ", type(sum_float))
# Out:
# Числовой массив: [1 2 3 4 5]
# Сумма значений: 15
# Среднее значение: 3.0
# Массив с плавающей точкой: [1.5 2.5 3.5 4.5 5.5]
# Сумма значений с плавающей точкой: 17.5 тип элемента  <class 'numpy.float64'>
# Среднее значение с плавающей точкой: 3.5 тип элемента  <class 'numpy.float64'>

# %% [markdown]
# <h5>Let's create decision for sum task with dict</h5>
# <p>Пример задачи: Управление базой данных студентов</p>

# %%
# Students
students = {
    "student1": {"name": "Alice", "age": 20, "gpa": 3.8},
    "student2": {"name": "Bob", "age": 22, "gpa": 3.5},
    "student3": {"name": "Charlie", "age": 21, "gpa": 3.9}
}

# Functions
def add_student(student_id, name, age, gpa):
    students[student_id] = {"name": name, "age": age, "gpa": gpa}

def get_student(student_id):
    return students.get(student_id, "Студент не найден")

add_student("student4", "Diana", 23, 3.7)

print(get_student("student1"))
print(get_student("student4"))
print(get_student("student5"))
# Out:
# {'name': 'Alice', 'age': 20, 'gpa': 3.8}
# {'name': 'Diana', 'age': 23, 'gpa': 3.7}
# Студент не найден

# %% [markdown]
# <h5>Another task for set</h5>
# <p>Пример задачи: Управление списком курсов</p>

# %%
courses_fall = {"Math 101", "Biology 201", "Chemistry 150"}
courses_spring = {"Physics 301", "Biology 201", "History 110"}

def add_course(semester, course):
    if semester == "fall":
        courses_fall.add(course)
    elif semester == "spring":
        courses_spring.add(course)

def common_courses():
    return courses_fall.intersection(courses_spring)

def unique_courses():
    return courses_fall.symmetric_difference(courses_spring)

add_course("fall", "Art 105")
add_course("spring", "Math 101")

print("Общие курсы:", common_courses())  # Вывод: {'Biology 201'}

print("Уникальные курсы:", unique_courses())  # Вывод: {'Art 105', 'Chemistry 150', 'History 110', 'Physics 301'}
# Out:
# Общие курсы: {'Math 101', 'Biology 201'}
# Уникальные курсы: {'Physics 301', 'Art 105', 'History 110', 'Chemistry 150'}

# %% [markdown]
# <h5>6) Introduction to str work</h5>
# <p>Task from stepik "Роскомнадзор запретил"</p>

# %%
# word = input() + ' запретил букву'
word = "Госзнак" + ' не одобрил букву'
alphabet = ['а', 'б', 'в', 'г', 'д', 'е', 'ж', 'з', 'и', 'й', 'к', 'л', 'м', 'н',
            'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'ш', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я']

for chr in alphabet:
    if(word.count(chr) > 0):
        print(word + f" {chr}")
        word = word.replace(chr, '')
        word = re.sub(r'\s+', ' ', word)
        
        if(len(word) == 0):
            break
        elif(word[0] == ' '):
            word = word[1::]
        elif(word[-1] == ' '):
            word = word[0::-2]
# Out:
# Госзнак не одобрил букву а
# Госзнк не одобрил букву б
# Госзнк не одорил укву в
# Госзнк не одорил уку д
# Госзнк не оорил уку е
# Госзнк н оорил уку з
# Госнк н оорил уку и
# Госнк н оорл уку к
# Госн н оорл уу л
# Госн н оор уу н
# Гос оор уу о
# Гс р уу р
# Гс уу с
# Г уу у

# %% [markdown]
# <h5>7) Import was in first code part</h5>
#
# <p> install.package() analog for Python in priviose block</p>
